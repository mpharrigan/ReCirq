# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

# %%
from recirq.algo_benchmarks.xx_model.single_noninteracting import SingleNoninteractingXxData, SingleNoninteractingXxSpec

assert SingleNoninteractingXxData, 'register deserializer'
assert SingleNoninteractingXxSpec, 'register deserializer'

from recirq.cirqflow.quantum_runtime import load_raw_results
run_id = 'testrun-2'
raw_results = load_raw_results(run_id)

# %%
from recirq.algo_benchmarks.xx_model.single_noninteracting import process_results, flat_results_to_dataframe
results = process_results(raw_results)
#df = flat_results_to_dataframe(results)

# %%
for res in results:
    print(res.z_densities)

# %%
for res in results:
    plt.scatter(np.arange(res.n_sites), res.z_densities, label=res.instance_i)
plt.legend(loc='best')
